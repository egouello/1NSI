# %% [markdown]
# Exercice 26 - Géographie
# ========================
#
# Les trois dictionnaires ci-dessous contiennent les villes de plus de 4 millions d'habitants d'après la liste https://public.opendatasoft.com/explore/dataset/worldcitiespop

# %%
villes_coordonnees = {
    "Rangoon": (96.1666667, 16.7833333),
    "New York": (-74.0063889, 40.7141667),
    "Baghdad": (44.3938889, 33.3386111),
    "Karachi": (67.0822, 24.9056),
    "Shanghai": (121.399722, 31.045556),
    "Mexico": (-99.138611, 19.434167),
    "Jakarta": (106.829444, -6.174444),
    "São Paulo": (-46.665803, -23.473293),
    "Tokyo": (139.751389, 35.685),
    "Seoul": (126.9783, 37.5985),
    "Calcutta": (88.369722, 22.569722),
    "Saint Petersburg": (30.264167, 59.894444),
    "Delhi": (77.216667, 28.666667),
    "Bangkok": (100.501444, 13.753979),
    "Manila": (120.9822, 14.6042),
    "Lagos": (3.395833, 6.453056),
    "Peking": (116.388333, 39.928889),
    "Moscow": (37.615556, 55.752222),
    "Istanbul": (28.964722, 41.018611),
    "Bombay": (72.825833, 18.975),
    "Bogotá": (-74.062827, 4.649178),
    "London": (-0.093689, 51.514125),
    "Madras": (80.283333, 13.083333),
    "Santiago": (-70.666667, -33.45),
    "Sydney": (151.205475, -33.861481),
    "New Delhi": (77.2, 28.6),
    "Lima": (-77.05, -12.05),
    "Lahore": (74.343611, 31.549722),
    "Kinshasa": (15.3, -4.3),
    "Cairo": (31.25, 30.05),
    "Bangalore": (77.583333, 12.983333),
    "Wuhan": (114.273405, 30.580125),
    "Toronto": (-79.416667, 43.666667),
    "Dhaka": (90.4086111, 23.7230556),
    "Rio de Janeiro": (-43.233333, -22.9),
}

villes_population = {
    "Rangoon": 4477782,
    "New York": 8107916,
    "Baghdad": 5672516,
    "Karachi": 11627378,
    "Shanghai": 14608512,
    "Mexico": 8720916,
    "Jakarta": 8540306,
    "São Paulo": 10021437,
    "Tokyo": 31480498,
    "Seoul": 10323448,
    "Calcutta": 4631819,
    "Saint Petersburg": 4039751,
    "Delhi": 10928270,
    "Bangkok": 5104475,
    "Manila": 10443877,
    "Lagos": 8789133,
    "Peking": 7480601,
    "Moscow": 10381288,
    "Istanbul": 9797536,
    "Bombay": 12692717,
    "Bogotá": 7102602,
    "London": 7421228,
    "Madras": 4328416,
    "Santiago": 4837248,
    "Sydney": 4394585,
    "New Delhi": 10928270,
    "Lima": 7646786,
    "Lahore": 6312576,
    "Kinshasa": 7787832,
    "Cairo": 7734602,
    "Bangalore": 4931603,
    "Wuhan": 4184206,
    "Toronto": 4612187,
    "Dhaka": 6493177,
    "Rio de Janeiro": 6023742,
}

villes_pays = {
    "Myanmar": ["Rangoon"],
    "États-Unis": ["New York"],
    "Irak": ["Baghdad"],
    "Pakistan": ["Karachi", "Lahore"],
    "Chine": ["Shanghai", "Peking", "Wuhan"],
    "Mexique": ["Mexico"],
    "Indonésie": ["Jakarta"],
    "Brésil": ["São Paulo", "Rio de Janeiro"],
    "Japon": ["Tokyo"],
    "Corée du Sud": ["Seoul"],
    "Inde": ["Calcutta", "Delhi", "Bombay", "Madras", "New Delhi", "Bangalore"],
    "Russie": ["Saint Petersburg", "Moscow"],
    "Thaïlande": ["Bangkok"],
    "Philippines": ["Manila"],
    "Nigeria": ["Lagos"],
    "Turquie": ["Istanbul"],
    "Colombie": ["Bogotá"],
    "Royaume-Uni": ["London"],
    "Chili": ["Santiago"],
    "Australie": ["Sydney"],
    "Pérou": ["Lima"],
    "République démocratique du Congo": ["Kinshasa"],
    "Égypte": ["Cairo"],
    "Canada": ["Toronto"],
    "Bangladesh": ["Dhaka"],
}

# %% [markdown]
# a) On dispose d’un dictionnaire `villes_coordonnees` qui associe à chaque nom de ville (chaîne) ses coordonnées sous forme d’un tuple (longitude, latitude). Afficher les noms de toutes les villes dont la latitude est inférieure à 23,43 degrés.

# %% [markdown]
# b) On dispose également d’un dictionnaire `villes_population` qui associe à chaque nom de ville (chaîne) son nombre d’habitants (entier). Afficher les coordonnées de la ville ayant le plus d’habitants.

# %% [markdown]
# c) On dispose enfin d’un dictionnaire `villes_pays` qui associe à chaque nom de pays (chaîne) un tableau de ses villes. Afficher le nombre total d’habitants des villes d’un pays donné et la latitude et la longitude moyenne de ces villes.

# %% [markdown]
# d) On présente ci-dessous le code permettant d'afficher un point sur une carte géographique grâce à la bibliothèque cartopy

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.Robinson())

# fabrique une carte globale
ax.set_global()

ax.stock_img()
#ax.coastlines() #ajoute les côtes

#on place un point rouge sur Montreal
ax.plot(-73.54,45.51, 'ro', transform=ccrs.PlateCarree())

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\Documents\GitHub\1NSI\venv\Lib\site-packages\cartopy\img_transform.py:16
#      15 try:
# ---> 16     from pykdtree.kdtree import KDTree as _kdtreeClass
#      17     _is_pykdtree = True
#
# ModuleNotFoundError: No module named 'pykdtree'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\Documents\GitHub\1NSI\venv\Lib\site-packages\cartopy\img_transform.py:20
#      19 try:
# ---> 20     from scipy.spatial import cKDTree as _kdtreeClass
#      21 except ImportError as e:
#
# ModuleNotFoundError: No module named 'scipy'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 10
#       7 # fabrique une carte globale
#       8 ax.set_global()
# ---> 10 ax.stock_img()
#      11 #ax.coastlines() #ajoute les côtes
#      12
#      13 #on place un point rouge sur Montreal
#      14 ax.plot(-73.54,45.51, 'ro', transform=ccrs.PlateCarree())
#
# File ~\Documents\GitHub\1NSI\venv\Lib\site-packages\cartopy\mpl\geoaxes.py:1015, in GeoAxes.stock_img(self, name)
#    1011     source_proj = ccrs.PlateCarree()
#    1012     fname = (config["repo_data_dir"] / 'raster' / 'natural_earth'
#    1013              / '50-natural-earth-1-downsampled.png')
# -> 1015     return self.imshow(imread(fname), origin='upper',
#    1016                        transform=source_proj,
#    1017                        extent=[-180, 180, -90, 90])
#    1018 else:
#    1019     raise ValueError('Unknown stock image %r.' % name)
#
# File ~\Documents\GitHub\1NSI\venv\Lib\site-packages\cartopy\mpl\geoaxes.py:315, in _add_transform.<locals>.wrapper(self, *args, **kwargs)
#     310     raise ValueError(f'Invalid transform: Spherical {func.__name__} '
#     311                      'is not supported - consider using '
#     312                      'PlateCarree/RotatedPole.')
#     314 kwargs['transform'] = transform
# --> 315 return func(self, *args, **kwargs)
#
# File ~\Documents\GitHub\1NSI\venv\Lib\site-packages\cartopy\mpl\geoaxes.py:1319, in GeoAxes.imshow(self, img, *args, **kwargs)
#    1315 regrid_shape = self._regrid_shape_aspect(regrid_shape,
#    1316                                          target_extent)
#    1317 # Lazy import because scipy/pykdtree in img_transform are only
#    1318 # optional dependencies
# -> 1319 from cartopy.img_transform import warp_array
#    1320 original_extent = extent
#    1321 img, extent = warp_array(img,
#    1322                          source_proj=transform,
#    1323                          source_extent=original_extent,
#    (...)
#    1327                          mask_extrapolated=True,
#    1328                          )
#
# File ~\Documents\GitHub\1NSI\venv\Lib\site-packages\cartopy\img_transform.py:22
#      20         from scipy.spatial import cKDTree as _kdtreeClass
#      21     except ImportError as e:
# ---> 22         raise ImportError("Using image transforms requires either "
#      23                           "pykdtree or scipy.") from e
#      24     _is_pykdtree = False
#      26 import cartopy.crs as ccrs
#
# ImportError: Using image transforms requires either pykdtree or scipy.
